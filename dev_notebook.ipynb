# %%
# Custom package to cheeck if required external packages are installed
import importlib.metadata
import pandas as pd

def check_packages(package_names):
    status = {}

    n_total = len(package_names)
    n_installed = 0
    package_df = pd.DataFrame(index=package_names, columns=["installed","not_installed"], data=0)

    for pkg in package_names:
        try:
            # metadata.version returns the version string if installed
            dist_version = importlib.metadata.version(pkg)
            status[pkg] = f"Installed (v{dist_version})"
            package_df.loc[pkg, "installed"] = 1
            n_installed += 1

        except importlib.metadata.PackageNotFoundError:
            status[pkg] = "Not Installed !!!"
            package_df.loc[pkg, "not_installed"] = 1
    
    print(f"> {n_installed}/{n_total} packages are installed:")

    for i in status:
        print(f"{i} package is {status[i]}")

    return package_df


installed_packages = check_packages(["pandas", "numpy", "scipy", "tqdm", "pandarallel", "mysql-connector-python"])
missing = installed_packages.loc[installed_packages.not_installed == 1, "not_installed"].index.to_list()

if len(missing) > 0:
    raise Exception(f"\nplease install required packages: {missing}")
# Out:
# > 5/6 packages are installed:
# pandas package is Installed (v2.2.3)
# numpy package is Installed (v2.1.3)
# scipy package is Installed (v1.14.1)
# tqdm package is Installed (v4.67.0)
# pandarallel package is Not Installed !!!
# mysql-connector-python package is Installed (v9.2.0)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[39], line 36
#      33 missing = installed_packages.loc[installed_packages.not_installed == 1, "not_installed"].index.to_list()
#      35 if len(missing) > 0:
# ---> 36     raise Exception(f"\nplease install required packages: {missing}")
#
# Exception:
# please install required packages: ['pandarallel']
